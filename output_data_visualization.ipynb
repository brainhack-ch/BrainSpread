# %% [markdown]
# # Visualizing the data

# %% [markdown]
# Here, we aim to visualize the data by using various python libraries

# %% [markdown]
# In the cell below, we import certain libraries that may be useful to us in this project

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# ## Patient AD4009

# %%
output_ad4009_rev = pd.read_csv("output/output/sub-AD4009/connect_matrix_reverted.csv")
print("reverted_matrix:")
plt.imshow(output_ad4009_rev)
plt.show()
# Out:
# reverted_matrix:

# %%
output_ad4009_rou = pd.read_csv("output/output/sub-AD4009/connect_matrix_rough.csv")
print("rough_matrix:")
plt.imshow(output_ad4009_rou)
plt.show()
# Out:
# rough_matrix:

# %% [markdown]
# ## Patient AD4215

# %%
output_ad4215_rev = pd.read_csv("output/output/sub-AD4215/connect_matrix_reverted.csv")
print("reverted_matrix:")
plt.imshow(output_ad4215_rev)
plt.show()
# Out:
# reverted_matrix:

# %%
output_ad4215_rou = pd.read_csv("output/output/sub-AD4215/connect_matrix_rough.csv")
print("rough_matrix:")
plt.imshow(output_ad4215_rou)
plt.show()
# Out:
# rough_matrix:

# %% [markdown]
# ## Patient AD4500

# %%
output_ad4500_rev = pd.read_csv("output/output/sub-AD4500/connect_matrix_reverted.csv")
print("reverted_matrix:")
plt.imshow(output_ad4500_rev)
plt.show()
# Out:
# reverted_matrix:

# %%
output_ad4500_rou = pd.read_csv("output/output/sub-AD4500/connect_matrix_rough.csv")
print("rough_matrix:")
plt.imshow(output_ad4500_rou)
plt.show()
# Out:
# rough_matrix:

# %% [markdown]
# ## Patient AD4892

# %%
output_ad4892_rev = pd.read_csv("output/output/sub-AD4892/connect_matrix_reverted.csv")
print("reverted_matrix:")
plt.imshow(output_ad4892_rev)
plt.show()
# Out:
# reverted_matrix:

# %%
output_ad4892_rou = pd.read_csv("output/output/sub-AD4892/connect_matrix_rough.csv")
print("rough_matrix:")
plt.imshow(output_ad4892_rou)
plt.show()
# Out:
# rough_matrix:

# %% [markdown]
# ## Patient AD6264

# %%
print("patient AD6264")

output_ad6264_rev = pd.read_csv("output/output/sub-AD6264/connect_matrix_reverted.csv")
print("reverted_matrix:")
plt.imshow(output_ad6264_rev)
plt.show()
# Out:
# patient AD6264
# reverted_matrix:

# %%
output_ad6264_rou = pd.read_csv("output/output/sub-AD6264/connect_matrix_rough.csv")
print("rough_matrix:")
plt.imshow(output_ad6264_rou)
plt.show()
# Out:
# rough_matrix:
